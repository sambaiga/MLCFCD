# %%
import sys
sys.path.append("../src")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd
import seaborn as sns
sns.color_palette('husl', n_colors=20)
from utils.visual_functions import *
# %matplotlib inline
fig_path="../paper/img/"
plaid_names = ['CFL','ILB','Waterkettle','Fan','AC','HairIron','LaptopCharger','SolderingIron','Fridge','Vacuum','CoffeeMaker','FridgeDefroster']

# %%
dataset="plaid"
width=50
model_name="CNN"
for image_type in ["vi"]:
    file_name = "CNNModel_plaid_vi_softmax"
    pred = np.load("../results/"+file_name+"_pred.npy")
    true = np.load("../results/"+file_name+"_true.npy")
    results = np.load("../results/"+file_name+"_results.npy", allow_pickle=True).item()
    results = pd.concat([results[1], results[2],  results[3],  results[4]], axis=1, join='inner')
    results['mean']=results.mean(axis=1)
    results['std']=results.std(axis=1)

# %%
results.round(3)
# Out:
#                 0      0      0      0   mean    std
# subACC      0.808  0.826  0.806  0.772  0.803  0.019
# JACC        0.863  0.858  0.852  0.823  0.849  0.016
# HA          0.982  0.980  0.979  0.975  0.979  0.002
# ebF1        0.935  0.936  0.938  0.921  0.932  0.007
# miF1        0.922  0.918  0.916  0.894  0.912  0.011
# maF1        0.921  0.918  0.913  0.891  0.911  0.012
# meanAUC     0.966  0.967  0.969  0.953  0.964  0.006
# medianAUC   0.971  0.983  0.972  0.975  0.975  0.005
# meanAUPR    0.926  0.923  0.922  0.901  0.918  0.010
# medianAUPR  0.935  0.936  0.918  0.935  0.931  0.007
# meanFDR     0.946  0.950  0.954  0.924  0.943  0.012
# medianFDR   0.952  0.983  0.959  0.960  0.964  0.012
# meanMCC     0.912  0.908  0.906  0.880  0.902  0.012
# medianMCC   0.921  0.924  0.898  0.924  0.917  0.011

# %%
cm = multilabel_confusion_matrix(true, pred)
#fig= figure(fig_width=12)
plot_confusion_matrix_multilabel(cm, plaid_names, classes=["OFF", "ON"], column=4, row=3, figsize=(12,6))
